# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import numpy as np

fashion_mnist = keras.datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# %% [markdown]
# # Well-fit Model

# %%
train_images = train_images / 255.0
test_images = test_images / 255.0

# %% [markdown]
# ### Build the Model

# %%
# set up the layers

model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(30, activation=tf.nn.relu),
    keras.layers.Dropout(0.1),
    keras.layers.Dense(100, activation=tf.nn.sigmoid)
])

# compile the model

model.compile(optimizer='adam',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

# train the model
epochs = 20
history = model.fit(train_images, 
                      train_labels, 
                      epochs=epochs,  
                      validation_data=(test_images, test_labels))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/20
# 60000/60000 [==============================] - 8s 128us/sample - loss: 0.8342 - acc: 0.7156 - val_loss: 0.5194 - val_acc: 0.8136
# Epoch 2/20
# 60000/60000 [==============================] - 7s 111us/sample - loss: 0.4837 - acc: 0.8309 - val_loss: 0.4500 - val_acc: 0.8418
# Epoch 3/20
# 60000/60000 [==============================] - 7s 112us/sample - loss: 0.4362 - acc: 0.8457 - val_loss: 0.4514 - val_acc: 0.8347
# Epoch 4/20
# 60000/60000 [==============================] - 7s 110us/sample - loss: 0.4109 - acc: 0.8523 - val_loss: 0.4135 - val_acc: 0.8544
# Epoch 5/20
# 60000/60000 [==============================] - 6s 104us/sample - loss: 0.3959 - acc: 0.8588 - val_loss: 0.4068 - val_acc: 0.8570
# Epoch 6/20
# 60000/60000 [==============================] - 7s 109us/sample - loss: 0.3813 - acc: 0.8622 - val_loss: 0.3892 - val_acc: 0.8601
# Epoch 7/20
# 60000/60000 [==============================] - 7s 109us/sample - loss: 0.3733 - acc: 0.8644 - val_loss: 0.3881 - val_acc: 0.8641
# Epoch 8/20
# 60000/60000 [==============================] - 7s 109us/sample - loss: 0.3652 - acc: 0.8684 - val_loss: 0.3835 - val_acc: 0.8612
# Epoch 9/20
# 60000/60000 [==============================] - 6s 105us/sample - loss: 0.3569 - acc: 0.8705 - val_loss: 0.3799 - val_acc: 0.8669
# Epoch 10/20
# 60000/60000 [==============================] - 6s 105us/sample - loss: 0.3518 - acc: 0.8709 - val_loss: 0.3913 - val_acc: 0.8651
# Epoch 11/20
# 60000/60000 [==============================] - 6s 105us/sample - loss: 0.3464 - acc: 0.8725 - val_loss: 0.3905 - val_acc: 0.8624
# Epoch 12/20
# 60000/60000 [==============================] - 6s 105us/sample - loss: 0.3409 - acc: 0.8749 - val_loss: 0.3772 - val_acc: 0.8666
# Epoch 13/20
# 60000/60000 [==============================] - 6s 106us/sample - loss: 0.3374 - acc: 0.8760 - val_loss: 0.3746 - val_acc: 0.8670
# Epoch 14/20
# 60000/60000 [==============================] - 6s 106us/sample - loss: 0.3334 - acc: 0.8778 - val_loss: 0.3813 - val_acc: 0.8666
# Epoch 15/20
# 60000/60000 [==============================] - 6s 107us/sample - loss: 0.3272 - acc: 0.8801 - val_loss: 0.3784 - val_acc: 0.8657
# Epoch 16/20
# 60000/60000 [==============================] - 6s 106us/sample - loss: 0.3250 - acc: 0.8793 - val_loss: 0.3728 - val_acc: 0.8693
# Epoch 17/20
# 60000/60000 [==============================] - 6s 102us/sample - loss: 0.3213 - acc: 0.8806 - val_loss: 0.3879 - val_acc: 0.8644
# Epoch 18/20
# 60000/60000 [==============================] - 6s 102us/sample - loss: 0.3177 - acc: 0.8820 - val_loss: 0.3754 - val_acc: 0.8695
# Epoch 19/20
# 60000/60000 [==============================] - 6s 107us/sample - loss: 0.3155 - acc: 0.8843 - val_loss: 0.3746 - val_acc: 0.8699
# Epoch 20/20
# 60000/60000 [==============================] - 6s 107us/sample - loss: 0.3119 - acc: 0.8843 - val_loss: 0.3746 - val_acc: 0.8715

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)

print('Test accuracy:', test_acc)
# Out:
# 10000/10000 [==============================] - 1s 58us/sample - loss: 0.3746 - acc: 0.8715
# Test accuracy: 0.8715

# %% [markdown]
# ### Loss and Accuracy Graph

# %%
history_dict = history.history
loss_values = history_dict['loss']
test_loss_values = history_dict['val_loss']
epochs_range = range(1, epochs+1)

# %%
plt.plot(epochs_range, loss_values, 'bo', label='Training loss')
plt.plot(epochs_range, test_loss_values, 'ro', label='Test loss')
plt.title('Training and test loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc_values = history_dict['acc']
test_acc_values = history_dict['val_acc']

# %%
plt.plot(epochs_range, acc_values, 'bo', label='Training accuracy')
plt.plot(epochs_range, test_acc_values, 'ro', label='Test accuracy')
plt.title('Training and test accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# # Overfit Model

# %% [markdown]
# ### Build the model

# %%
# set up the layers

model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(70, activation=tf.nn.relu),
    keras.layers.Dense(40, activation=tf.nn.softmax)
])

# compile the model

model.compile(optimizer='adam',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

# train the model
epochs = 20
history = model.fit(train_images, 
                      train_labels, 
                      epochs=epochs,  
                      validation_data=(test_images, test_labels))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/20
# 60000/60000 [==============================] - 8s 130us/sample - loss: 0.5474 - acc: 0.8137 - val_loss: 0.5063 - val_acc: 0.8121
# Epoch 2/20
# 60000/60000 [==============================] - 6s 102us/sample - loss: 0.4069 - acc: 0.8572 - val_loss: 0.4769 - val_acc: 0.8356
# Epoch 3/20
# 60000/60000 [==============================] - 6s 100us/sample - loss: 0.3674 - acc: 0.8681 - val_loss: 0.4171 - val_acc: 0.8459
# Epoch 4/20
# 60000/60000 [==============================] - 6s 100us/sample - loss: 0.3390 - acc: 0.8770 - val_loss: 0.3775 - val_acc: 0.8668
# Epoch 5/20
# 60000/60000 [==============================] - 7s 113us/sample - loss: 0.3188 - acc: 0.8837 - val_loss: 0.3820 - val_acc: 0.8628
# Epoch 6/20
# 60000/60000 [==============================] - 7s 110us/sample - loss: 0.3023 - acc: 0.8892 - val_loss: 0.3804 - val_acc: 0.8640
# Epoch 7/20
# 60000/60000 [==============================] - 6s 102us/sample - loss: 0.2926 - acc: 0.8921 - val_loss: 0.3648 - val_acc: 0.8672
# Epoch 8/20
# 60000/60000 [==============================] - 6s 101us/sample - loss: 0.2837 - acc: 0.8944 - val_loss: 0.3510 - val_acc: 0.8720
# Epoch 9/20
# 60000/60000 [==============================] - 6s 101us/sample - loss: 0.2726 - acc: 0.8981 - val_loss: 0.3447 - val_acc: 0.8795
# Epoch 10/20
# 60000/60000 [==============================] - 6s 104us/sample - loss: 0.2647 - acc: 0.9004 - val_loss: 0.3714 - val_acc: 0.8674
# Epoch 11/20
# 60000/60000 [==============================] - 6s 102us/sample - loss: 0.2585 - acc: 0.9044 - val_loss: 0.3500 - val_acc: 0.8763
# Epoch 12/20
# 60000/60000 [==============================] - 6s 103us/sample - loss: 0.2497 - acc: 0.9077 - val_loss: 0.3371 - val_acc: 0.8807
# Epoch 13/20
# 60000/60000 [==============================] - 6s 104us/sample - loss: 0.2457 - acc: 0.9090 - val_loss: 0.3556 - val_acc: 0.8782
# Epoch 14/20
# 60000/60000 [==============================] - 6s 102us/sample - loss: 0.2388 - acc: 0.9111 - val_loss: 0.3532 - val_acc: 0.8747
# Epoch 15/20
# 60000/60000 [==============================] - 6s 99us/sample - loss: 0.2317 - acc: 0.9141 - val_loss: 0.3536 - val_acc: 0.8776
# Epoch 16/20
# 60000/60000 [==============================] - 6s 105us/sample - loss: 0.2284 - acc: 0.9145 - val_loss: 0.3470 - val_acc: 0.8834
# Epoch 17/20
# 60000/60000 [==============================] - 6s 101us/sample - loss: 0.2227 - acc: 0.9162 - val_loss: 0.3505 - val_acc: 0.8808
# Epoch 18/20
# 60000/60000 [==============================] - 6s 98us/sample - loss: 0.2187 - acc: 0.9176 - val_loss: 0.3486 - val_acc: 0.8818
# Epoch 19/20
# 60000/60000 [==============================] - 6s 99us/sample - loss: 0.2144 - acc: 0.9201 - val_loss: 0.3642 - val_acc: 0.8804
# Epoch 20/20
# 60000/60000 [==============================] - 6s 99us/sample - loss: 0.2100 - acc: 0.9217 - val_loss: 0.3513 - val_acc: 0.8808

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)

print('Test accuracy:', test_acc)
# Out:
# 10000/10000 [==============================] - 1s 59us/sample - loss: 0.3513 - acc: 0.8808
# Test accuracy: 0.8808

# %% [markdown]
# ### Loss and Accuracy Graph

# %%
history_dict = history.history
loss_values = history_dict['loss']
test_loss_values = history_dict['val_loss']
epochs_range = range(1, epochs+1)

# %%
plt.plot(epochs_range, loss_values, 'bo', label='Training loss')
plt.plot(epochs_range, test_loss_values, 'ro', label='Test loss')
plt.title('Training and test loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc_values = history_dict['acc']
test_acc_values = history_dict['val_acc']

# %%
plt.plot(epochs_range, acc_values, 'bo', label='Training accuracy')
plt.plot(epochs_range, test_acc_values, 'ro', label='Test accuracy')
plt.title('Training and test accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# # Underfit Model

# %% [markdown]
# ### Build the Model

# %%
# set up the layers

model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(20, activation=tf.nn.relu),
    keras.layers.Dense(20, activation=tf.nn.relu),
    keras.layers.Dense(80, activation=tf.nn.relu)
])

# compile the model

model.compile(optimizer='adam',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

# train the model
epochs = 10
history = model.fit(train_images, 
                      train_labels, 
                      epochs=epochs,  
                      validation_data=(test_images, test_labels))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 8s 129us/sample - loss: 3.5259 - acc: 0.3022 - val_loss: 3.9221 - val_acc: 0.2057
# Epoch 2/10
# 60000/60000 [==============================] - 6s 102us/sample - loss: 4.2077 - acc: 0.1406 - val_loss: 4.3579 - val_acc: 0.1055
# Epoch 3/10
# 60000/60000 [==============================] - 6s 101us/sample - loss: 4.3364 - acc: 0.1106 - val_loss: 4.2520 - val_acc: 0.1300
# Epoch 4/10
# 60000/60000 [==============================] - 6s 101us/sample - loss: 4.2986 - acc: 0.1197 - val_loss: 4.3729 - val_acc: 0.1022
# Epoch 5/10
# 60000/60000 [==============================] - 6s 100us/sample - loss: 4.2921 - acc: 0.1207 - val_loss: 4.3606 - val_acc: 0.1049
# Epoch 6/10
# 60000/60000 [==============================] - 6s 101us/sample - loss: 4.3190 - acc: 0.1145 - val_loss: 4.3097 - val_acc: 0.1165
# Epoch 7/10
# 60000/60000 [==============================] - 6s 102us/sample - loss: 4.3097 - acc: 0.1166 - val_loss: 4.3413 - val_acc: 0.1093
# Epoch 8/10
# 60000/60000 [==============================] - 6s 102us/sample - loss: 4.3172 - acc: 0.1148 - val_loss: 4.2949 - val_acc: 0.1201
# Epoch 9/10
# 60000/60000 [==============================] - 6s 102us/sample - loss: 4.3492 - acc: 0.1075 - val_loss: 4.3443 - val_acc: 0.1086
# Epoch 10/10
# 60000/60000 [==============================] - 6s 101us/sample - loss: 4.3298 - acc: 0.1119 - val_loss: 4.2983 - val_acc: 0.1191

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)

print('Test accuracy:', test_acc)
# Out:
# 10000/10000 [==============================] - 1s 55us/sample - loss: 4.2983 - acc: 0.1191
# Test accuracy: 0.1191

# %% [markdown]
# ### Loss and Accuracy Graph

# %%
history_dict = history.history
loss_values = history_dict['loss']
test_loss_values = history_dict['val_loss']
epochs_range = range(1, epochs+1)

# %%
plt.plot(epochs_range, loss_values, 'bo', label='Training loss')
plt.plot(epochs_range, test_loss_values, 'ro', label='Test loss')
plt.title('Training and test loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc_values = history_dict['acc']
test_acc_values = history_dict['val_acc']

# %%
plt.plot(epochs_range, acc_values, 'bo', label='Training accuracy')
plt.plot(epochs_range, test_acc_values, 'ro', label='Test accuracy')
plt.title('Training and test accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
